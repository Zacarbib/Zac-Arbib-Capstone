# %%
# !pip install openai sentence-transformers -q

# %%
# !unzip -q hai-diversity-main.zip

# %%
from google.colab import userdata
import os
os.environ["OPENAI_API_KEY"] = userdata.get("OPENAI_API_KEY")

# %%
# !python study2_generate.py --pilot
# Out:
# === Study 2 generation - PILOT (format check only - outputs are NOT analysed) ===
# Model gpt-5.5, reasoning_effort=low, 20 calls, ~300-word essays.
#
# Prompts to be used verbatim from the corpus:
#    1. Should Schools Teach Mindfulness?
#    2. How Worried Should We Be About Screen Time
#    3. How Do You Think Technology Affects Dating?
#    4. What Stereotypical Characters Make You Cringe?
#    5. Is It Wrong to Focus on Animal Welfare When Humans Are Suffering?
#    6. Are We Being Bad Citizens If We Don't Keep Up With the News?
#    7. Is Listening to a Book Just as Good as Reading It?
#    8. Should College Athletes Be Paid?
#    9. Is It Selfish to Pursue Risky Sports Like Extreme Mountain Climbing?
#   10. What Are the Most Important Things Students Should Learn in School?
#
# Type 'yes' to proceed and spend API credit: Yes
# [1/20] default | Should Schools Teach Mindfulness? | slot 0
# [2/20] default | How Worried Should We Be About Screen Time | slot 0
# ...

# %%
# !echo "15 July 2026: Pilot review found model-generated text uses typographic punctuation (curly apostrophes) while the human corpus is overwhelmingly ASCII, creating a systematic tokenisation artefact in MTLD. Normalisation of typographic punctuation to ASCII added to the analysis pipeline, applied uniformly to all corpora, before any confirmatory analysis was run." >> study2_deviations.md

# %%
# !python study2_generate.py
# Out:
# === Study 2 generation - FULL RUN ===
# Model gpt-5.5, reasoning_effort=low, 200 calls, ~300-word essays.
#
# Prompts to be used verbatim from the corpus:
#    1. Should Schools Teach Mindfulness?
#    2. How Worried Should We Be About Screen Time
#    3. How Do You Think Technology Affects Dating?
#    4. What Stereotypical Characters Make You Cringe?
#    5. Is It Wrong to Focus on Animal Welfare When Humans Are Suffering?
#    6. Are We Being Bad Citizens If We Don't Keep Up With the News?
#    7. Is Listening to a Book Just as Good as Reading It?
#    8. Should College Athletes Be Paid?
#    9. Is It Selfish to Pursue Risky Sports Like Extreme Mountain Climbing?
#   10. What Are the Most Important Things Students Should Learn in School?
#
# Type 'yes' to proceed and spend API credit: Yes
# [1/200] default | Should Schools Teach Mindfulness? | slot 0
# [2/200] default | Should Schools Teach Mindfulness? | slot 1
# [3/200] default | Should Schools Teach Mindfulness? | slot 2
# ...

# %%
# !python study2_analysis.py
# Out:
# ...
# modules.json: 100% 349/349 [00:00<00:00, 991kB/s]
# config_sentence_transformers.json: 100% 116/116 [00:00<00:00, 367kB/s]
# README.md: 100% 11.6k/11.6k [00:00<00:00, 16.8MB/s]
# sentence_bert_config.json: 100% 53.0/53.0 [00:00<00:00, 153kB/s]
# config.json: 100% 571/571 [00:00<00:00, 1.49MB/s]
# model.safetensors: 100% 438M/438M [00:02<00:00, 147MB/s]
# Loading weights: 100% 199/199 [00:00<00:00, 17905.15it/s]
# tokenizer_config.json: 100% 363/363 [00:00<00:00, 663kB/s]
# vocab.txt: 100% 232k/232k [00:00<00:00, 4.19MB/s]
# tokenizer.json: 100% 466k/466k [00:00<00:00, 14.8MB/s]
# special_tokens_map.json: 100% 239/239 [00:00<00:00, 755kB/s]
# config.json: 100% 190/190 [00:00<00:00, 602kB/s]
# STUDY 2 RESULTS - embedding mode: SBERT all-mpnet-base-v2
# run: 2026-07-15T15:08:41.587304+00:00  seed: 20260707  N_PERM=10000  N_BOOT=10000
# ...
# condition       n           MTLD         convergence         words
# solo           99      90.1 (21.3)       0.7656 (0.0810)             -
# ...

# %%
from google.colab import files
files.download('study2_results.txt')
files.download('fig_spectrum.png')
files.download('study2_essays.jsonl')
files.download('study2_raw.jsonl')
files.download('study2_generation_log.json')
files.download('study2_per_essay.csv')

# %%
# !pip install sentence-transformers -q
# !unzip -q hai-diversity-main.zip
# !python study2_analysis.py
# Out:
# ...
# modules.json: 100% 349/349 [00:00<00:00, 1.37MB/s]
# config_sentence_transformers.json: 100% 116/116 [00:00<00:00, 202kB/s]
# README.md: 100% 11.6k/11.6k [00:00<00:00, 24.6MB/s]
# sentence_bert_config.json: 100% 53.0/53.0 [00:00<00:00, 249kB/s]
# config.json: 100% 571/571 [00:00<00:00, 2.77MB/s]
#
# model.safetensors: downloading bytes:  56% 243M/438M [00:03<00:01, 116MB/s, 21.4MB/s  ]
# model.safetensors: downloading bytes:  67% 296M/438M [00:03<00:01, 125MB/s, 23.7MB/s  ]
# model.safetensors: downloading bytes:  95% 414M/438M [00:04<00:00, 88.9MB/s, 33.0MB/s  ]
# model.safetensors: downloading bytes: 100% 414M/414M [00:05<00:00, 81.5MB/s, 32.9MB/s  ]
# model.safetensors: reconstructing file: 100% 438M/438M [00:05<00:00, 86.2MB/s, 36.4MB/s  ]
# Loading weights: 100% 199/199 [00:00<00:00, 12640.52it/s]
# tokenizer_config.json: 100% 363/363 [00:00<00:00, 1.23MB/s]
# vocab.txt: 100% 232k/232k [00:00<00:00, 22.6MB/s]
# tokenizer.json: 100% 466k/466k [00:00<00:00, 27.1MB/s]
# ...
