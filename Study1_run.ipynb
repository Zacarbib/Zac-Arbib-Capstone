# %%
# !pip install sentence-transformers -q

# %%
# !unzip -q hai-diversity-main.zip

# %%
# !python study1_pipeline.py
# Out:
# Loaded 297 essays. Embedding with SBERT all-mpnet-base-v2...
# modules.json: 100% 349/349 [00:00<00:00, 1.63MB/s]
# ...
# config_sentence_transformers.json: 100% 116/116 [00:00<00:00, 53.3kB/s]
# README.md: 100% 11.6k/11.6k [00:00<00:00, 23.9MB/s]
# sentence_bert_config.json: 100% 53.0/53.0 [00:00<00:00, 396kB/s]
# config.json: 100% 571/571 [00:00<00:00, 2.46MB/s]
# model.safetensors: 100% 438M/438M [00:04<00:00, 99.4MB/s]
# Loading weights: 100% 199/199 [00:00<00:00, 23021.47it/s]
# tokenizer_config.json: 100% 363/363 [00:00<00:00, 1.26MB/s]
# vocab.txt: 100% 232k/232k [00:00<00:00, 14.4MB/s]
# tokenizer.json: 100% 466k/466k [00:00<00:00, 51.5MB/s]
# special_tokens_map.json: 100% 239/239 [00:00<00:00, 1.17MB/s]
# config.json: 100% 190/190 [00:00<00:00, 1.12MB/s]
#
# STUDY 1 RESULTS — embedding mode: SBERT all-mpnet-base-v2
# ...
# condition       n            MTLD       convergence    user-only conv
# solo           99     90.0 (20.8)   0.7658 (0.0805)                 —
# ...

# %%
from google.colab import files
files.download('study1_results.txt')
files.download('study1_per_essay.csv')
